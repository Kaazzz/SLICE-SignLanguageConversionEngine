# %%
# !pip install opencv-python scikit-learn matplotlib 
# !pip install mediapipe tensorflow==2.16.1
# !pip install picamera2

import mediapipe as mp
import cv2
import numpy as np
import os
import time
from matplotlib import pyplot as plt
from picamera2 import Picamera2

# MediaPipe setup
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False  
    results = model.process(image)
    image.flags.writeable = True   
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return image, results

def draw_styled_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS)
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS)
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# Actions
actions = np.array(['hello', 'thanks', 'iloveyou'])

# Load Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))
model.load_weights('action.h5')

# Raspberry Pi Camera Setup
picam = Picamera2()
picam.preview_configuration.main.size = (1280, 720)
picam.preview_configuration.main.format = "RGB888"
picam.configure("preview")
picam.start()

sequence = []
sentence = []
predictions = []
threshold = 0.5

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while True:
        frame = picam.capture_array()  # Capture image from Pi Cam
        frame = cv2.flip(frame, 1)  # Flip horizontally for a natural mirror effect

        image, results = mediapipe_detection(frame, holistic)
        draw_styled_landmarks(image, results)
        
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        detected_action = ""
        res = np.zeros(len(actions))  # Default empty predictions
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            predictions.append(np.argmax(res))
            
            if np.unique(predictions[-10:])[0] == np.argmax(res): 
                if res[np.argmax(res)] > threshold:
                    detected_action = actions[np.argmax(res)]
                    if not sentence or detected_action != sentence[-1]:
                        sentence.append(detected_action)

            if len(sentence) > 5:
                sentence = sentence[-5:]

        # UI Overlay
        overlay = image.copy()
        cv2.rectangle(overlay, (0, 0), (1280, 60), (0, 0, 0), -1)
        cv2.rectangle(overlay, (0, 680), (600, 720), (0, 0, 0), -1)
        alpha = 0.6
        cv2.addWeighted(overlay, alpha, image, 1 - alpha, 0, image)

        # Display Detected Action
        text_size = cv2.getTextSize(detected_action.upper(), cv2.FONT_HERSHEY_PLAIN, 2, 2)[0]
        text_x = (1280 - text_size[0]) // 2
        cv2.putText(image, detected_action.upper(), (text_x, 45), cv2.FONT_HERSHEY_PLAIN, 2, (0, 0, 0), 6, cv2.LINE_AA)
        cv2.putText(image, detected_action.upper(), (text_x, 45), cv2.FONT_HERSHEY_PLAIN, 2, (255, 255, 255), 3, cv2.LINE_AA)

        # Display Video Frame
        cv2.imshow('Sign Language Recognition', image)

        # Exit on 'q' key
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cv2.destroyAllWindows()
picam.close()
# Out:
# Requirement already satisfied: opencv-python in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (4.11.0.86)
# Requirement already satisfied: scikit-learn in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (1.6.1)
# Requirement already satisfied: matplotlib in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (3.9.4)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mediapipe in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (0.10.21)
# Requirement already satisfied: tensorflow==2.16.1 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow==2.16.1) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.13.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.4.0)
# Requirement already satisfied: packaging in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (1.71.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.9.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (1.26.4)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: jax in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from mediapipe) (0.4.30)
# Requirement already satisfied: jaxlib in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from mediapipe) (0.4.30)
# Requirement already satisfied: matplotlib in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from mediapipe) (3.9.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: sentencepiece in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: scipy>=1.9 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from jax->mediapipe) (1.13.1)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from jax->mediapipe) (8.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from matplotlib->mediapipe) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from matplotlib->mediapipe) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from matplotlib->mediapipe) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from matplotlib->mediapipe) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from matplotlib->mediapipe) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from matplotlib->mediapipe) (6.5.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.45.1)
# Requirement already satisfied: pycparser in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: zipp>=3.20 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from importlib-metadata>=4.6->jax->mediapipe) (3.21.0)
# Requirement already satisfied: rich in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (13.9.4)
# Requirement already satisfied: namex in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.0.8)
# Requirement already satisfied: optree in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.1.2)
# Collecting picamera2
#   Downloading picamera2-0.3.25-py3-none-any.whl.metadata (6.4 kB)
# Collecting PiDNG (from picamera2)
#   Downloading pidng-4.0.9.tar.gz (21 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting av (from picamera2)
#   Downloading av-14.2.0-cp39-cp39-win_amd64.whl.metadata (4.8 kB)
# Requirement already satisfied: jsonschema in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from picamera2) (4.23.0)
# Collecting libarchive-c (from picamera2)
#   Downloading libarchive_c-5.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: numpy in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from picamera2) (1.26.4)
# Collecting piexif (from picamera2)
#   Downloading piexif-1.1.3-py2.py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pillow in c:\users\zak\anaconda3\envs\myvenv\lib\site-packages (from picamera2) (11.1.0)
# Collecting python-prctl (from picamera2)
#   Downloading python-prctl-1.8.1.tar.gz (28 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [1 lines of output]
#   This module only works on linux
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 11
#       9 import time
#      10 from matplotlib import pyplot as plt
# ---> 11 from picamera2 import Picamera2
#      13 # MediaPipe setup
#      14 mp_holistic = mp.solutions.holistic
#
# ModuleNotFoundError: No module named 'picamera2'
